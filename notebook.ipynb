# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama: Muhammad Fachrurrozi
# - Email: m189d4ky2144@bangkit.academy
# - Id Dicoding: m_fachrurrozi

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - produk mana yang paling laku?
# - berapa rata rata uang yang dihabiskan oleh kustomer?
# - lokasi geofrafis mana yang memiliki paling banyak kustomer?

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import urllib
import matplotlib.image as mpimg
from scipy import stats

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Inisialisasi setiap file dataset
orders = pd.read_csv("data/orders_dataset.csv")
items = pd.read_csv("data/order_items_dataset.csv")
products = pd.read_csv("data/products_dataset.csv")
payments = pd.read_csv("data/order_payments_dataset.csv")
reviews = pd.read_csv("data/order_reviews_dataset.csv")
customers = pd.read_csv("data/customers_dataset.csv")
sellers = pd.read_csv("data/sellers_dataset.csv")
geolocation = pd.read_csv("data/geolocation_dataset.csv")
category = pd.read_csv("data/product_category_name_translation.csv")

data = {'orders': orders,
        'items': items,
        'products': products,
        'payments': payments,
        'reviews': reviews,
        'customers': customers,
        'sellers': sellers,
        'geo': geolocation,
        'category': category}

# %%
data['customers'].head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
data['items'].head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
data['products'].head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %%
data["payments"].head(10)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5  298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6  771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7  3d7239c394a212faae122962df514ac7                   1  credit_card
# 8  1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9  0573b5e23cbd798006520e1d5b4c6714                   1       boleto
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# ...

# %%
data['reviews'].head(10)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8  a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# ...

# %%
data['customers'].head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
data['sellers'].head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
data['geo'].head(10)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
# 5                         1012       -23.547762       -46.635361
# 6                         1047       -23.546273       -46.641225
# 7                         1013       -23.546923       -46.634264
# 8                         1029       -23.543769       -46.634278
# 9                         1011       -23.547640       -46.636032
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP
# ...

# %%
data['category'].head(10)
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# 5           esporte_lazer                sports_leisure
# 6              perfumaria                     perfumery
# 7   utilidades_domesticas                    housewares
# 8               telefonia                     telephony
# 9      relogios_presentes                 watches_gifts

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **mengecek type data**

# %%
for df in data:
    print(df)
    print('\n', data[df].info())
# Out:
# orders
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
#
#  None
# items
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ...

# %%
#mengubah tipe data menjadi datetime untuk beberapa kolom di orders
datetime_orders = ['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date']
for column in datetime_orders:
    data['orders'][column] = pd.to_datetime(data['orders'][column])

#mengubah shipping_limit_date menjadi tipe date datetime pada items
data['items']['shipping_limit_date'] = pd.to_datetime(data['items']['shipping_limit_date'])

#mengubah tipe data menjadi datetime untuk beberapa kolom di reviews
datetime_reviews = ['review_creation_date','review_answer_timestamp']
for column in datetime_reviews:
    data['reviews'][column] = pd.to_datetime(data['reviews'][column])

# %% [markdown]
# **mengecek duplikasi pada data**

# %%
#inisialisasi dictionary untuk menyimpan jumlah duplikasi dan total sample
dupllicate_counts, total_sample_count = {},{}

#menghitung jumlah duplikasi dan total sample untuk setiap dataframe
for df_name, df in data.items():
    dupllicate_counts[df_name] = df.duplicated().sum()
    total_sample_count[df_name] = len(df)

#membuat dataframe dari dictionary
dupllicate_counts_df = pd.DataFrame.from_dict(dupllicate_counts,orient='index',columns=['dupllicate count'])
total_sample_count_df = pd.DataFrame.from_dict(total_sample_count, orient='index',columns=['total sample count'])

#menggabungkan dua  dataframe tersebut dengan concat
pd.concat([total_sample_count_df,dupllicate_counts_df],axis=1)
# Out:
#            total sample count  dupllicate count
# orders                  99441                 0
# items                  112650                 0
# products                32951                 0
# payments               103886                 0
# reviews                 99224                 0
# customers               99441                 0
# sellers                  3095                 0
# geo                   1000163            261831
# category                   71                 0

# %% [markdown]
# **mengecek missing values pada data**

# %%
#inisialisasi sebuah dictionary untuk menyimpan nilai null dari dataframe
null_counts = {}

#hitung nilai null pada setiap dataframe
for df_name, df in data.items():
 null_counts[df_name] = df.isna().sum()
 print(df_name, '\n', null_counts[df_name],'\n')
# Out:
# orders
#  order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# items
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# products
#  product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# payments
#  order_id                0
# payment_sequential      0
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# - **Orders data**

# %%
# mencetak jumlah status pesanan dalam data
print(data['orders']['order_status'].value_counts())
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
print('Pesanan yang telah dikirimkan: ' + str(round((data['orders'].order_status.value_counts()['delivered']/len(data['orders']))*100,2)) + "% dari data.")
# Out:
# Pesanan yang telah dikirimkan: 97.02% dari data.

# %%
#cari semua data order_id yang order statusnya delivered kemudian filter
#semua dataframe yang memiliki order_id sebagai foreign key

delivered = data['orders']['order_id'][data['orders']['order_status'] != 'delivered'].values

for df_name, df in data.items():
    if 'order_id' in df.columns:
        df.drop(df.loc[df['order_id'].isin(delivered)].index, inplace = True)

# %%
#cek nilai NaN pada setiap dataset
for df_name, df in data.items():
    for col in df.columns:
        if df[col].isnull().sum():
            print(col + '(%) : '+str((sum(df[col].isnull())/len(df))*100))
# Out:
# order_approved_at(%) : 0.014511080246273761
# order_delivered_carrier_date(%) : 0.0020730114637533947
# order_delivered_customer_date(%) : 0.008292045855013579
# product_category_name(%) : 1.8512336499650999
# product_name_lenght(%) : 1.8512336499650999
# product_description_lenght(%) : 1.8512336499650999
# product_photos_qty(%) : 1.8512336499650999
# product_weight_g(%) : 0.006069618524475737
# product_length_cm(%) : 0.006069618524475737
# product_height_cm(%) : 0.006069618524475737
# product_width_cm(%) : 0.006069618524475737
# review_comment_title(%) : 88.36873839001255
# review_comment_message(%) : 59.4244559520968

# %%
# Memeriksa nilai NaN dalam kolom tertentu dalam dataframe pesanan
missing_delivery_dates = data['orders'].order_delivered_customer_date.isnull().sum()
print( str(missing_delivery_dates) +
      ' pesanan tidak ada tanggal pengiriman')
# Out:
# 8 pesanan tidak ada tanggal pengiriman

# %%
# Kita dapat menghapusnya dengan cara yang sama seperti sebelumnya
# pertama dapatkan semua order_id di mana status pesanannya telah dikirim
null_deliveries = data['orders']['order_id'][data['orders']['order_delivered_customer_date'].isnull()].values

# sekarang, filter setiap dataframe lain di mana order_id adalah kunci asing
for df_name, df in data.items():
    if 'order_id' in df.columns:
        df.drop(df.loc[df['order_id'].isin(null_deliveries)].index, inplace=True)

# %%
# Jika pesanan dikirimkan sebelum atau pada tanggal perkiraan pengiriman, maka anggap 'On Time', jika tidak, anggap 'Late'.
data['orders']['delivered_on_time'] = np.where(data['orders']['order_delivered_customer_date'] <= data['orders']['order_estimated_delivery_date'], 'On Time', 'Late')

# %% [markdown]
# - **Review**

# %%
#pada reviews kolom review_comment_title 88%nya Nan jadi akan di cleaning dengan drop
data['reviews'].drop('review_comment_title', axis=1, inplace = True)
print('kolom kolom review: ', data['reviews'].columns.values)
# Out:
# kolom kolom review:  ['review_id' 'order_id' 'review_score' 'review_comment_message'
#  'review_creation_date' 'review_answer_timestamp']

# %%
#pada kolom review_comment_message akan ada nilai Nan jika customer tidak mengisi ulasan
#jadi ubah saja nilai Nan dengan 0 dan non Nan dengna 1
data['reviews']['review_comment_message'] = np.where(data['reviews']['review_comment_message'].isnull(), 0, 1)

# %% [markdown]
# - **products**

# %%
#Panjang nama atau deskripsi produk tidak menarik karena terlalu banyak nilai NaN. 
#Atribut ukuran setiap produk juga tidak memiliki kegunaan.
kolom_produk_diabaikan = ['product_name_lenght',
                          'product_description_lenght',
                          'product_weight_g',
                          'product_length_cm',
                          'product_height_cm',
                          'product_width_cm']

# Hapus kolom yang tidak diperlukan dari dataframe produk
data['products'].drop(columns=kolom_produk_diabaikan, inplace=True)
# Cetak nama kolom dalam dataframe produk
print('Kolom Produk: ', data['products'].columns.values)
# Out:
# Kolom Produk:  ['product_id' 'product_category_name' 'product_photos_qty']

# %%
#assumsikan bisa mengganti nilai nan yang ada dengan "other"
data['products']['product_category_name'].fillna(value='other',inplace=True)
# Out:
# /tmp/ipykernel_9101/2659231739.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['products']['product_category_name'].fillna(value='other',inplace=True)

# %%
#untuk kolom product_photos_qty kita coba isi nilai nan dengan nol
data['products']['product_photos_qty'] = data['products']['product_photos_qty'].fillna(value=0)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Customer

# %%
data['customers'].sample(10)
# Out:
#                             customer_id                customer_unique_id  \
# 67141  7ec5b53960d508118d7a3126af968d44  edfa9c76eb9296cf40024cc3b079ed95
# 29253  a0a88da4a6858c8d7cc650bbd21949e8  d9a5ebf62ff59b5cef9e4e36b6a76f7e
# 42089  37bf6ca0a677445a3f521046ba630f78  8165d55b87871cd256280ddd432c51ad
# 27095  7c4b8e956f27bed90b8269e5a04ac6db  52cf485027691709f7b6124df189763e
# 65078  1b05680a264c3a8ef32e8062cd965438  1e2ce8e4f49582730eb003ac5f1712d0
# 27094  ce26ced2b3dbcd2e283ad3c688021fec  7da4f6efe547aa814499bbbf226859bc
# 9642   d53fb7b713c6e34a7c69768003c82a59  79427e2162d316b713fc8c37a16e7fb5
# 2638   5a5f70fead43dc16ec4d5afed5281239  b1cf91f7efd99001549d2eafa05c66c1
# 62403  06ea718b69bcb8f124ac69512c21c231  a6e17e76c0bb659bc2fd0e002e46407d
# 97756  0002414f95344307404f0ace7a26f1d5  4893ad4ea28b2c5b3ddf4e82e79db9e6
#
#        customer_zip_code_prefix        customer_city customer_state
# 67141                     25953          teresopolis             RJ
# ...

# %%
data['customers'].groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
data['customers'].groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore Payments

# %%
data['payments'].sample(10)
# Out:
#                                order_id  payment_sequential payment_type  \
# 55079  cdd3f73daec692a65c1cb65c46154b84                   1  credit_card
# 2015   d5355dced21ef64e6f081ec25945fbd6                   1  credit_card
# 19741  f5967f0a9a614d8ccb6b2c1c16bde5ed                   1  credit_card
# 64431  664141bb6dcd20117425954f2bae35ca                   1  credit_card
# 92609  00c42b1633c1b2fa4e937bf312466561                   1  credit_card
# 45279  adeecc8758fde854ecaaa035e0ae212e                   1       boleto
# 22093  b9b862b71dd3a13f37bbb72f2addc949                   1  credit_card
# 17457  b7d6c506d31d5537a7abea4378a1a7fb                   1  credit_card
# 69836  ccaa7f476eec8a9922ac7193691d310b                   1  credit_card
# 10244  0071ee2429bc1efdc43aa3e073a5290e                   1      voucher
#
#        payment_installments  payment_value
# 55079                     1          91.96
# 2015                      4         109.77
# ...

# %%
data['payments'].groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    74297
# boleto         19191
# voucher         3679
# debit_card      1484
# Name: order_id, dtype: int64

# %%
data['orders'].sample(10)
# Out:
#                                order_id                       customer_id  \
# 71156  f5d7c7844669e4addcf57dd9c9b703a5  437ab8c619c372caf63fc4b6c8117290
# 41588  6ef2a7cbf8c6fb24f0acb656c756a44a  cf51d3ab484330d9c266cd7e83fa37df
# 16253  ad366003d331bb0eaa77c1efc5570657  d54371af4fe03138c67f7ad33c8986f2
# 41113  ba57df46d6c7801e304a57084265bd86  6132860a5328ff1bcb9571bc0040b78d
# 22085  1436cba3294812a22fe0868db7581b68  662b50538fbec2fa00feb3d4e7135b93
# 40422  cd746ffbf9ea117c1706f37c61f73621  a6e47b0794b9bda3bbd7a62d975932a8
# 59394  768fa69faa8e49e877dd1612013472f6  ffa9419903b6e1ed6f0692ab2695de94
# 15666  2e714c63b48a7f01b1bcd40c2621b813  608d1467c0aa3e122509bbe443173525
# 67424  dd936caa925da4ddcfc308b3c788f643  af3cefcdf63b8f9f8f86f3bdbd41a7da
# 97771  ce8a790838d6b4304ddde9481438c679  f21be72df342026508f9072dba657632
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 71156    delivered      2018-04-09 11:22:45 2018-04-09 11:30:17
# ...

# %%
data['orders']['delivered_on_time'].describe()
# Out:
# count       96470
# unique          2
# top       On Time
# freq        88644
# Name: delivered_on_time, dtype: object

# %% [markdown]
# ## Explore customers & orders

# %% [markdown]
# - Merge customers dengan orders

# %%
customers_orders_df = pd.merge(
    left=data['customers'],
    right=data['orders'],
    how='left',
    left_on='customer_id',
    right_on='customer_id'
)
customers_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# - Merge payment dengan reviews

# %%
payments_reviews_df = pd.merge(
    left=data['payments'],
    right=data['reviews'],
    how="left",
    left_on="order_id",
    right_on="order_id"
)
payments_reviews_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score  review_comment_message review_creation_date  \
# ...

# %%
payments_reviews_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 50839  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 33495  736e1922ae60d0d6a89247b851902527                   1       boleto
# 40402  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 48364  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 83426  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 62912  25b5b0ea53b7d5a2d5712a0d9d0b3649                   1  credit_card
# 61160  45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 98277  b23878b3e8eb4d25a158f57d96331b18                   4      voucher
# 19418  8bcbe01d44d147f901cd3192671144db                   4      voucher
# 42671  6ccb433e00daae1283ccc956189c82ae                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
payments_reviews_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19191         11.62   7274.88
# credit_card     74297          0.01  13664.08
# debit_card       1484         13.38   4445.50
# voucher          3679          0.00   1839.05

# %% [markdown]
# - Merge customers_orders dengan paysments_reviews

# %%
customers_df = pd.merge(
    left=customers_orders_df,
    right=payments_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ## Explore items & sellers
# - Merge items dengan sellers

# %%
item_seller_df = pd.merge(
    left=data['items'],
    right=data['sellers'],
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
item_seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
item_seller_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         661
# curitiba          124
# rio de janeiro     92
# belo horizonte     65
# ribeirao preto     50
# ibitinga           49
# guarulhos          48
# santo andre        44
# maringa            40
# campinas           40
# Name: seller_id, dtype: int64

# %%
item_seller_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1769
# PR     335
# MG     236
# SC     184
# RJ     163
# RS     125
# GO      39
# DF      30
# ES      22
# BA      18
# Name: seller_id, dtype: int64

# %% [markdown]
# ## Explore products & category
# - Merge products dengan category

# %%
product_df = pd.merge(
    left=data['products'],
    right=data['category'],
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty product_category_name_english
# 0                 1.0                     perfumery
# 1                 1.0                           art
# 2                 1.0                sports_leisure
# 3                 1.0                          baby
# 4                 4.0                    housewares

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
product_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# - Merge item_seller_df dengan product_df

# %%
sellers_df = pd.merge(
    left=product_df,
    right=item_seller_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sellers_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty product_category_name_english  \
# 0                 1.0                     perfumery
# 1                 1.0                           art
# 2                 1.0                sports_leisure
# 3                 1.0                          baby
# 4                 4.0                    housewares
#
#                            order_id  order_item_id  \
# 0  e17e4f88e31525f7deef66779844ddce            1.0
# 1  5236307716393b7114b53ee991f36956            1.0
# 2  01f66e58769f84129811d43eefd187fb            1.0
# 3  143d00a4f2dde4e0364ee1821577adb3            1.0
# ...

# %%
sellers_df.sort_values(by="price", ascending=False)
# Out:
#                               product_id  product_category_name  \
# 20210   489ae2aa008f021502940f251d4cce7f  utilidades_domesticas
# 72816   69c590f7ffc7bf8db97190b6cb6ed62e                    pcs
# 48744   1bdf5e6731585cf01aa8169c7028d6ad                  artes
# 70764   a6492cc69376c469ab6f61d8f44de961        eletroportateis
# 31736   c3ed642d592594bb648ff4a04cee2747        eletroportateis
# ...                                  ...                    ...
# 110167  5cac6a83708526b99c11e11027ae1ca6       moveis_decoracao
# 110244  17c7ec33a1657924ad493e6978b4bf91                  bebes
# 110304  03b10f5e3ef07cfc27a025adca3fd0be          esporte_lazer
# 110470  70adb75b3b2e86cffbb697c90867c3f3       moveis_decoracao
# 110848  4e1d2ef2974c85d82582edfe594a4f57          esporte_lazer
#
#         product_photos_qty product_category_name_english  \
# 20210                  2.0                    housewares
# 72816                  4.0                     computers
# ...

# %%
sellers_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         177  12.99  2990.00
# air_conditioning                   246  10.90  1599.00
# art                                195   5.35  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              348  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2264   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4093   5.00  2428.00
# toys                              3803   4.90  1699.99
# watches_gifts                     5493   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# ## Explore geo

# %%
data['geo'].sample(10)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 991807                        98470       -27.333731       -53.057039
# 398910                        19160       -22.100499       -51.451561
# 810871                        76380       -15.333847       -49.124220
# 308785                        13420       -22.739374       -47.606514
# 33915                          2615       -23.472158       -46.652694
# 7883                           1322       -23.563000       -46.643791
# 189739                         7434       -23.413240       -46.319214
# 661821                        39414       -26.888998       -49.056093
# 830920                        78885       -12.375224       -54.932851
# 621067                        36860       -21.155371       -42.216029
#
#             geolocation_city geolocation_state
# 991807              planalto                RS
# 398910       alvares machado                SP
# 810871             goianesia                GO
# ...

# %%
data['geo'].groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
data['geo'][data['geo']['geolocation_zip_code_prefix'] == 24230].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470806                        24230       -22.911270       -43.105151
# 470807                        24230       -22.905032       -43.114682
# 470810                        24230       -22.909753       -43.101880
# 470816                        24230       -22.908945       -43.108600
# 470817                        24230       -22.906274       -43.103573
#
#        geolocation_city geolocation_state
# 470806          niterói                RJ
# 470807          niterói                RJ
# 470810          niteroi                RJ
# 470816          niteroi                RJ
# 470817          niteroi                RJ

# %% [markdown]
# ## Explore All Data
# - Merge All data

# %%
all_data = pd.merge(
    left=customers_df,
    right=sellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head(20)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7   5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8   5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9   4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10  9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11  5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# ...

# %%
all_data_df = all_data.drop_duplicates('order_id')

# %%
all_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96471 entries, 0 to 2305341
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    96471 non-null  object
#  1   customer_unique_id             96471 non-null  object
#  2   customer_zip_code_prefix       96471 non-null  int64
#  3   customer_city                  96471 non-null  object
#  4   customer_state                 96471 non-null  object
#  5   order_id                       96470 non-null  object
#  6   order_status                   96470 non-null  object
#  7   order_purchase_timestamp       96470 non-null  datetime64[ns]
#  8   order_approved_at              96456 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   96469 non-null  datetime64[ns]
#  10  order_delivered_customer_date  96470 non-null  datetime64[ns]
# ...

# %%
all_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum",

}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 40494     7455331.70
# RJ                 12350     2699623.08
# MG                 11354     2290457.39
# RS                  5344     1118250.44
# PR                  4923     1036003.69
# BA                  3256      775836.28
# SC                  3546      769234.50
# GO                  1957      497367.84
# DF                  2080      424872.44
# ES                  1995      399308.36
# PE                  1593      362434.77
# CE                  1279      335018.17
# PA                   946      255609.57
# MT                   886      251859.09
# MA                   717      195528.31
# PB                   517      177485.32
# MS                   701      164556.97
# PI                   476      133729.03
# RN                   474      115203.08
# AL                   397      108727.76
# SE                   335       85694.32
# TO                   274       70934.12
# ...

# %%
all_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "mean",

}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# PB                   517     284.431603
# AC                    80     264.792447
# AP                    67     259.297711
# RR                    41     245.671304
# AL                   397     244.332045
# PI                   476     241.388141
# MA                   717     237.579964
# PA                   946     233.007812
# MT                   886     232.771802
# RO                   243     232.030819
# CE                  1279     222.751443
# SE                   335     222.006010
# TO                   274     212.377605
# GO                  1957     207.669244
# RN                   474     204.623588
# AM                   145     203.448118
# PE                  1593     196.975418
# BA                  3256     196.414248
# MS                   701     194.053031
# SC                  3546     181.466030
# RJ                 12350     180.419908
# PR                  4923     175.772598
# ...

# %%
all_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         177          1.0  5.0
# air_conditioning                   246          1.0  5.0
# art                                195          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              348          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2264          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4093          1.0  5.0
# toys                              3803          1.0  5.0
# watches_gifts                     5493          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# - Simpan all_data_df ke file csv baru

# %%
all_data_df.to_csv("dashboard/main.csv",index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk mana yang paling laku?

# %%
# Menggabungkan dataset 'items' dengan dataset 'products' berdasarkan kolom 'product_id' dengan metode inner join
items_product = data['items'].merge(data['products'], on='product_id', how='inner')

# Menggabungkan hasilnya dengan dataset 'orders' berdasarkan kolom 'order_id' dengan metode inner join
orders_ip = data['orders'].merge(items_product, on='order_id', how='inner')

# Membuat tabel pivot yang mengagregasi berdasarkan jumlah item yang dibeli dan rata-rata harga produk
product_revenue = orders_ip.pivot_table(index=['product_id'], aggfunc={'order_item_id': 'sum', 'price': 'mean'})
product_revenue['total'] = product_revenue['order_item_id'] * product_revenue['price']
product_revenue.rename(columns={'order_item_id': 'sell_probability'}, inplace=True)
product_revenue['sell_probability'] = product_revenue['sell_probability'] / len(product_revenue)
product_revenue.sort_values(by='total', ascending=False)
# Out:
#                                   sell_probability        price         total
# product_id
# bb50f2e236e5eea0100680137654686c          0.006643   327.628866  70112.577320
# 5769ef0a239114ac3a854af00df129e4          0.001118  1680.000000  60480.000000
# 6cdd53843498f92890544667809f1595          0.004998   350.668627  56457.649020
# d1c427060a0f73f6b889a5c7c61f2ac4          0.011082   137.411325  49055.843133
# 99a4788cb24856965c36a24e339b6058          0.016484    88.154423  46809.998868
# ...                                            ...          ...           ...
# 8a3254bee785a526d548a81a9bc3c9be          0.000124     0.850000      3.400000
# 2e8316b31db34314f393806fd7b6e185          0.000031     2.990000      2.990000
# 680cc8535be7cc69544238c1d6a83fe8          0.000031     2.900000      2.900000
# 310dc32058903b6416c71faff132df9e          0.000031     2.290000      2.290000
# 46fce52cef5caa7cc225a5531c946c8b          0.000031     2.200000      2.200000
#
# ...

# %% [markdown]
# * Membuat plotting probabilitas penjualan produk, harga, dan pendapatan.

# %%
# Fungsi kustom untuk menetapkan desain plot
def custom_plot(ax, spines):
    for loc, spine in ax.spines.items():
        if loc in spines:
            spine.set_position(('outward', 10))
        else:
            spine.set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

x = np.log(product_revenue.sell_probability)
y = np.log(product_revenue.price)

fig, ax = plt.subplots(figsize=(8, 6))
custom_plot(ax, ['bottom', 'left'])

plt.title('Harga Produk vs. Probabilitas Penjualan', fontsize=16)
plt.xlabel('Log Probabilitas Penjualan', fontsize=12)
plt.ylabel('Log Harga Produk', fontsize=12)

plt.xlim(-11, -3)
plt.ylim(0, 9)

plt.yticks(range(10), [int(np.exp(x)) for x in range(10)], fontsize=10)
plt.xticks(range(-10, -2), [round(np.exp(x), 4) for x in range(-10, -2)], fontsize=10, rotation=30)

# Menggunakan colormaps yang berbeda dan menetapkan jumlah grid
hb = ax.hexbin(x, y, gridsize=14, C=product_revenue.total, reduce_C_function=np.sum, cmap='viridis') # Ubah ke colormap 'viridis'

# Menambahkan colorbar
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Pendapatan Produk (R$)', rotation=270, labelpad=20, fontsize=12)

# Menyesuaikan tata letak dan menyimpan gambar
plt.tight_layout()
plt.savefig('data/product_probability_sum_custom.png', dpi=300)

plt.show()

# %% [markdown]
# *Kita dapat mengatakan bahwa produk-produk yang menghasilkan pendapatan terbanyak adalah barang-barang dengan harga menengah yang sering terjual.*

# %% [markdown]
# ### Pertanyaan 2: Berapa rata rata uang yang dihabiskan oleh kustomer?

# %%
# merge dataset pelanggan dengan dataset orders dan payments
pay_ord_cust = orders.merge(payments, on='order_id', how='outer').merge(customers, on='customer_id', how='outer')

# Menghitung customer spent
customer_spent = pay_ord_cust.groupby('customer_unique_id').agg({'payment_value': 'sum'}).sort_values(by='payment_value', ascending=False)

# Menghitung rata-rata cutomer spent dan standar deviasi
customer_mean = customer_spent['payment_value'].mean()
customer_std = stats.sem(customer_spent['payment_value'])

# Memprediksi rata-rata populasi dari sampel
stats.t.interval(0.95, loc=customer_mean, scale= customer_std, df= len(customer_spent)- 1)
# Out:
# (159.05473856062326, 161.8968692066095)

# %%
# Menghitung rata-rata dan interval kepercayaan untuk pelanggan di setiap wilayah
customer_regions = pay_ord_cust.groupby('customer_state').agg({'payment_value':['mean', 'std'], 'customer_unique_id':'count'})
customer_regions.reset_index(inplace=True)

cis = stats.t.interval(0.95, loc=customer_regions['payment_value']['mean'], scale=customer_regions['payment_value']['std']/np.sqrt(customer_regions['customer_unique_id']['count']), df=customer_regions['customer_unique_id']['count'] - 1)

customer_regions['ci_low'] = cis[0]
customer_regions['ci_hi'] = cis[1]

# %%
# matplotlib adjustments
def default_plot(ax, spines):
    ax = plt.gca()
    # Hapus sumbu yang tidak perlu
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    ax.get_yaxis().set_tick_params(direction='out', width=1.5) 
    ax.get_xaxis().set_tick_params(direction='out', width=1.5) 

    for loc, spine in ax.spines.items():
        if loc in spines:
            spine.set_position(('outward', 10)) 

    if 'left' in spines:
        ax.yaxis.set_ticks_position('left')

    if 'right' in spines:
        ax.yaxis.set_ticks_position('right')

    if 'bottom' in spines:
        ax.xaxis.set_ticks_position('bottom')

    return ax

# Urutkan secara ascending agar plot yang lebih mudah dibaca
plot = customer_regions.sort_values(by=('payment_value', 'mean'))

# buat figurenya
fig, ax = plt.subplots(figsize=(12, 4))
ax = default_plot(ax, ['left', 'bottom'])
plt.xticks(rotation=30)
plt.xlabel('State')
plt.ylabel('Rata-rata Transaksi (95% CI)')
plt.xlim(-0.5, 26.5)
plt.ylim(125, 325)
plt.scatter(plot['customer_state'], plot['payment_value']['mean'], s=100, c=plot['payment_value']['mean'], cmap='viridis') # Ubah pola warnanya
plt.vlines(plot['customer_state'], plot['ci_low'], plot['ci_hi'], lw=0.5)
plt.tight_layout()
plt.savefig('data/customers_ci.png', dpi=300)

# %% [markdown]
# ### Pertanyaan 3: lokasi geofrafis mana yang memiliki paling banyak kustomer?

# %%
other_state_geolocation = data['geo'].groupby(['geolocation_zip_code_prefix'])['geolocation_state'].nunique().reset_index(name='count')
other_state_geolocation[other_state_geolocation['count']>= 2].shape
max_state = data['geo'].groupby(['geolocation_zip_code_prefix','geolocation_state']).size().reset_index(name='count').drop_duplicates(subset = 'geolocation_zip_code_prefix').drop('count',axis=1)

# %%
geolocation_silver = data['geo'].groupby(['geolocation_zip_code_prefix','geolocation_city','geolocation_state'])[['geolocation_lat','geolocation_lng']].median().reset_index()
geolocation_silver = geolocation_silver.merge(max_state,on=['geolocation_zip_code_prefix','geolocation_state'],how='inner')

# %%
customers_silver = customers_df.merge(geolocation_silver,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='inner')

# %%
customers_silver.head(20)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 3   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 4   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 5   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 6   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 7   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 8   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 9   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 10  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 11  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# ...

# %%
customers_silver = customers_silver.drop_duplicates('order_id')

# %%
customers_silver.to_csv("dashboard/geolocation.csv", index=False)

# %%
def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen('https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'),'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3, s=0.3, c='blue') 
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
    plt.show()

# %%
plot_brazil_map(customers_silver.drop_duplicates(subset='customer_unique_id'))

# %% [markdown]
# banyak customers berasal dari southeastern dan southern states.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * produk mana yang paling laku?</br>
# jawab: produk yang paling laku adalah produk kelas menengah yang berada pada range harga sekitar 50-500 R$
#
# * berapa rata rata uang yang dihabiskan oleh kustomer? dan lokasinya?</br>
# jawab:
# joao pessoa(PB) dengan rata rata 284.43 Rs
#
# * lokasi geofrafis mana yang memiliki paling banyak kustomer?</br>
# jawab: kustomer paling banyak berada pada bagian south/selatan dan sounthest/tenggara(sao paulo, rio de janeiro,dan lain lian)
